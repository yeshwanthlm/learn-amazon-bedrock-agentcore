# %% [markdown]
# # Module 01 — Hello, Agent!
#
# This is the simplest possible Strands agent. No tools, no memory, no hooks — just a model and a message.
#
# ### What is Strands?
#
# **Strands Agents** is an open-source SDK from AWS that lets you build AI agents with minimal boilerplate. Under the hood it:
# - Manages the conversation loop (user → model → tool → model → ...)
# - Handles tool calling automatically
# - Integrates with Amazon Bedrock models
# - Provides hooks for lifecycle events
#
# The core primitive is the `Agent` class. Let's use it.

# %%
# !uv pip install -r ../requirements.txt

# %%
from strands import Agent

# Create the simplest possible agent. By default it uses Claude 3.7 Sonnet via Amazon Bedrock
agent = Agent()

# Invoke it — just like calling a function
response = agent("Hello! Who are you and what can you do?")
# Out:
# Hello! I'm Claude, an AI assistant created by Anthropic. I'm here to help with a wide variety of tasks through conversation.
#
# Some things I can help with include:
#
# - **Analysis and research** - I can help break down complex topics, analyze information, and discuss ideas
# - **Writing assistance** - From creative writing to editing, structuring documents, or brainstorming
# - **Problem-solving** - Working through challenges step-by-step, whether practical or conceptual
# - **Learning support** - Explaining concepts, helping with homework, or exploring new subjects
# - **Programming help** - Writing code, debugging, explaining programming concepts
# - **Creative projects** - Brainstorming, storytelling, worldbuilding, or other creative endeavors
# - **General conversation** - Discussing topics you're interested in or just having a friendly chat
#
# I aim to be helpful, harmless, and honest in our interactions. I can engage with most topics, though I do have some limitations - I can't browse the internet, generate images, or remember our conversation once it ends.
#
# What would you like to explore or work on together?

# %% [markdown]
# That's it. One import, one object, one call.
#
# ---
#
# ### Choosing a model
#
# You can specify any Bedrock model using its cross-region inference profile ID.

# %%
# Use Claude 3.5 Haiku — faster and cheaper, great for workshops
agent = Agent(
    model="us.anthropic.claude-3-5-haiku-20241022-v1:0"
)

response = agent("What is 2 + 2? Answer in one sentence. /n")

# %% [markdown]
# ### Multi-turn conversation
#
# The agent keeps conversation history automatically. Each call to `agent(...)` continues the same thread.

# %%
agent = Agent(model="us.anthropic.claude-3-5-haiku-20241022-v1:0")

agent("My name is Yeshwanth.")
agent("I live in India. I run a YouTube Channel: Tech With Yeshwanth. Please consider Subscribing")

# The agent remembers the conversation context within the same session
response = agent("What do you know about me so far?")

# %% [markdown]
# ### Inspecting the agent
#
# You can look at the messages the agent has accumulated.

# %%
# See the raw conversation history
for msg in agent.messages:
    role = msg['role']
    content = msg['content']
    # content is a list of content blocks
    text = content[0].get('text', '') if content else ''
    print(f"[{role.upper()}]: {text[:100]}..." if len(text) > 100 else f"[{role.upper()}]: {text}")

# %% [markdown]
# ---
#
# ### Key takeaways
#
# - `Agent()` is all you need to get started
# - Pass `model=` to choose a Bedrock model
# - Calling `agent("...")` continues the conversation
# - `agent.messages` holds the full history
#
# Next up: **02_runtime-setup.ipynb** — giving the agent real capabilities with custom tools.
